# %% [markdown]
# This notebook is used for extracting the features from extrinsic data (Microphone). This is done using the feature extraction library called Librosa which can handle audio .wav files.

# %%
import os
import librosa
import pandas as pd
import numpy as np  #pip install librosa and resampy

# %% [markdown]
# A function is created which automatically extracts a list of pre-chosen features from a given audio file. It then returns these features in an array with all the numerical values.

# %%
def extract_features(file_path):
    try:
        audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast') 
        n_fft = 512  # Lower value for FFT window

        # Check if audio is shorter than n_fft and pad if necessary
        if len(audio) < n_fft:
            audio = np.pad(audio, (0, n_fft - len(audio)), 'constant')

        chroma_stft = librosa.feature.chroma_stft(y=audio, sr=sample_rate, n_fft=n_fft)
        spec_contrast = librosa.feature.spectral_contrast(y=audio, sr=sample_rate, n_fft=n_fft)
        tonnetz = librosa.feature.tonnetz(y=audio, sr=sample_rate)
        mfcc = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40, n_fft=n_fft)
        spectral_bandwidth = librosa.feature.spectral_bandwidth(y=audio, sr=sample_rate, n_fft=n_fft)
        zero_crossing_rate = librosa.feature.zero_crossing_rate(audio)
        spectral_rolloff = librosa.feature.spectral_rolloff(y=audio, sr=sample_rate, n_fft=n_fft)

        features = [np.mean(chroma_stft), np.mean(spec_contrast), np.mean(tonnetz), np.mean(spectral_bandwidth), np.mean(zero_crossing_rate), np.mean(spectral_rolloff)] + [np.mean(e) for e in mfcc]

    except Exception as e:
        print("Error encountered while parsing file: ", file_path)
        return None 

    return features

# %% [markdown]
# Now we can create the dataframe which will hold our features. We define the columns as our pre-chosen features and append the filename of the .wav clip aswell. Then we create an empty pandas dataframe to hold all the extrinsic features. Then a loop goes through all the audio files in the specified directory and extracts the features into a data dictionary. A data dictionary is basically just an array with column names and data combined, but we want it to be formatted in the dataframe for later perpouses. So we simply convert the dictionary by mapping each value in it, to its corresponding column in the dataframe. Once we have converted the dictionary to a dataframe we can merge it with our previously created feature dataframe using the concatenate merger.

# %%
# directory containing your audio files
root_dir = r"C:\Users\kaspe\Documents\GitHub\AAU-IoT-Solution-AI-REDGIO\data_ozren\Extrinsic data" # replace with your directory

# Construct the column names
column_names = ['chroma_stft', 'spec_contrast', 'tonnetz', 'spectral_bandwidth', 'zero_crossing_rate', 'spectral_rolloff'] + [f'mfcc_{i}' for i in range(1, 41)]

# add 'filename' to the column names
column_names.append('filename')

# Create a dataframe that will hold the features
features_df = pd.DataFrame(columns = column_names)

# Walk through the directory (and subdirectories)
for subdir, dirs, files in os.walk(root_dir):
    for file in files:
        # Only process .wav files
        if file.endswith(".wav"):
            file_path = subdir + os.sep + file
            data = extract_features(file_path)

            # Extract the base file name without extension
            filename = os.path.splitext(os.path.basename(file_path))[0]

            # Add the features to the dataframe
            data_dict = {column_names[i]: data[i] for i in range(len(data))}
            data_dict['filename'] = filename
            features_df = pd.concat([features_df, pd.DataFrame([data_dict])], ignore_index=True) #Older projects used pd.append, but this is deprecated in pandas 2.0 and newer. Note to self: remember to check for this
# Out:
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=664
#   warnings.warn(
# C:\Users\kaspe\AppData\Local\Temp\ipykernel_32756\968371886.py:27: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   features_df = pd.concat([features_df, pd.DataFrame([data_dict])], ignore_index=True) #Ozren used pd.append, but this is deprecated in pandas 2.0 and newer
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=568
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=768
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=728
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=736
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=744
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=760
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=720
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=752
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=784
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=792
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=712
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=704
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=776
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=672
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=696
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=688
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=616
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=800
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=560
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=632
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=912
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=808
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=864
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=816
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=848
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=824
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=680
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=600
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=624
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=512
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=544
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=528
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=552
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=576
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=520
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=592
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=1008
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=504
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=536
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=640
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=584
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=944
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=472
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=992
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=496
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=608
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=648
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=960
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=480
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=976
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=488
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=456
#   warnings.warn(
# c:\Users\kaspe\anaconda3\envs\MachineLearning\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=840
#   warnings.warn(

# %% [markdown]
# For later purposes we want the filename (currently eg: e2012010141) to be reformatted to be an id in the format: id2012010141. This is to easily match the extrinsic features with the intrinsic and task features.

# %%
# Filter rows where filename starts with 'e'
features = features_df[features_df['filename'].str.startswith('e')]

# Replace 'e' at the start of filenames with 'id'
features['filename'] = features['filename'].str.replace('^e', 'id', regex=True)

# Rename the column
features = features.rename(columns={'filename': 'id'})

print(features)
# Out:
#       chroma_stft  spec_contrast   tonnetz  spectral_bandwidth  \
# 